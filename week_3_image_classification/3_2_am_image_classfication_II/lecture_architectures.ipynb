# %% [markdown]
# # Architectures

# %% [markdown]
# ![winter1516_lecture7 78](images/winter1516_lecture7 78.png)

# %% [markdown]
# ![winter1516_lecture7 60](images/winter1516_lecture7 60.png)

# %% [markdown]
# ![winter1516_lecture7 68](images/winter1516_lecture7 68.png)

# %% [markdown]
# ![winter1516_lecture7 69](images/winter1516_lecture7 69.png)

# %% [markdown]
# ![winter1516_lecture7 71](images/winter1516_lecture7 71.png)

# %% [markdown]
# ![winter1516_lecture7 72](images/winter1516_lecture7 72.png)

# %% [markdown]
# ![winter1516_lecture7 73](images/winter1516_lecture7 73.png)

# %% [markdown]
# ![winter1516_lecture7 74](images/winter1516_lecture7 74.png)

# %%
from keras.applications import VGG16

vggnet = VGG16()
vggnet.summary(line_length=75, positions=[0.5, 0.9, 1.0, 1.0])
# Out:
# ___________________________________________________________________________
# Layer (type)                         Output Shape                  Param #
# ...
# input_5 (InputLayer)                 (None, 224, 224, 3)           0
# ___________________________________________________________________________
# block1_conv1 (Conv2D)                (None, 224, 224, 64)          1792
# ___________________________________________________________________________
# block1_conv2 (Conv2D)                (None, 224, 224, 64)          36928
# ___________________________________________________________________________
# block1_pool (MaxPooling2D)           (None, 112, 112, 64)          0
# ___________________________________________________________________________
# block2_conv1 (Conv2D)                (None, 112, 112, 128)         73856
# ___________________________________________________________________________
# block2_conv2 (Conv2D)                (None, 112, 112, 128)         147584
# ...

# %% [markdown]
# ![winter1516_lecture7 75](images/winter1516_lecture7 75.png)

# %% [markdown]
# ![winter1516_lecture7 76](images/winter1516_lecture7 76.png)

# %%
from keras.applications.inception_v3 import InceptionV3

googlenet = InceptionV3()
googlenet.summary(line_length=75, positions=[0.5, 0.9, 1.0, 1.0])
# Out:
# ...
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_3 (InputLayer)             (None, 299, 299, 3)   0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 149, 149, 32)  864
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 149, 149, 32)  96
# ____________________________________________________________________________________________________
# activation_50 (Activation)       (None, 149, 149, 32)  0
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 147, 147, 32)  9216
# ...

# %% [markdown]
# ![winter1516_lecture7 77](images/winter1516_lecture7 77.png)

# %%
from keras.applications.resnet50 import ResNet50

resnet = ResNet50()
print(f'layers: {len(resnet.layers)}')
resnet.summary(line_length=75, positions=[0.5, 0.9, 1.0, 1.0])
# Out:
# layers: 177
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_2 (InputLayer)             (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D) (None, 230, 230, 3)   0
# ____________________________________________________________________________________________________
# conv1 (Conv2D)                   (None, 112, 112, 64)  9472
# ____________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)    (None, 112, 112, 64)  256
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 112, 112, 64)  0
# ...

# %% [markdown]
# ![winter1516_lecture7 80](images/winter1516_lecture7 80.png)

# %% [markdown]
# ![winter1516_lecture7 83](images/winter1516_lecture7 83.png)

# %% [markdown]
# ![winter1516_lecture7 85](images/winter1516_lecture7 85.png)

# %% [markdown]
# ![winter1516_lecture7 89](images/winter1516_lecture7 89.png)
