# %% [markdown]
# # Multi-Class Logistic Regression
#
# - Grid-search over regularization term

# %%
from train import ex
import keras.backend as K

for reg in [1e-1, 1e-6, 1e-12]:
    ex.run(config_updates={'reg': reg})
    K.clear_session()
# Out:
# Using TensorFlow backend.
# INFO - test - Running command 'main'
# WARNING - test - No observers have been added to this run
# INFO - test - Started
# /Users/edward.banner/Documents/DSCI6005/instructor/week_5_reinforcement_learning/5_2_pm_nn_training_II/instructor/code/trainers.py:16: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=10, kernel_regularizer=<keras.reg...)`
#   model.add(Dense(units=self.Y[0].shape[0], W_regularizer=l2(self.C['reg'])))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                7850
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________
# Train on 54000 samples, validate on 6000 samples
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO - tensorflow - Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO - tensorflow - Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# Epoch 1/5
# 54000/54000 [==============================] - 5s - loss: 1.4417 - acc: 0.8152 - val_loss: 1.2928 - val_acc: 0.8760
# Epoch 2/5
# 54000/54000 [==============================] - 5s - loss: 1.3548 - acc: 0.8334 - val_loss: 1.2913 - val_acc: 0.8712
# Epoch 3/5
# 54000/54000 [==============================] - 8s - loss: 1.3511 - acc: 0.8330 - val_loss: 1.2816 - val_acc: 0.8693
# Epoch 4/5
# 54000/54000 [==============================] - 9s - loss: 1.3496 - acc: 0.8311 - val_loss: 1.2874 - val_acc: 0.8597
# Epoch 5/5
# 54000/54000 [==============================] - 6s - loss: 1.3494 - acc: 0.8304 - val_loss: 1.2839 - val_acc: 0.8752
# INFO - test - Completed after 0:00:38
# INFO - test - Running command 'main'
# WARNING - test - No observers have been added to this run
# INFO - test - Started
# /Users/edward.banner/Documents/DSCI6005/instructor/week_5_reinforcement_learning/5_2_pm_nn_training_II/instructor/code/trainers.py:16: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=10, kernel_regularizer=<keras.reg...)`
#   model.add(Dense(units=self.Y[0].shape[0], W_regularizer=l2(self.C['reg'])))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                7850
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________
# Train on 54000 samples, validate on 6000 samples
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO - tensorflow - Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO - tensorflow - Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# Epoch 1/5
# 54000/54000 [==============================] - 6s - loss: 0.4921 - acc: 0.8719 - val_loss: 0.2751 - val_acc: 0.9265
# Epoch 2/5
# 54000/54000 [==============================] - 5s - loss: 0.3146 - acc: 0.9130 - val_loss: 0.2434 - val_acc: 0.9330
# Epoch 3/5
#  - ETA: 4s - loss: 0.3024 - acc: 0.9150
# Epoch 4/5
# 54000/54000 [==============================] - 6s - loss: 0.2810 - acc: 0.9213 - val_loss: 0.2316 - val_acc: 0.9385
# Epoch 5/5
# 54000/54000 [==============================] - 5s - loss: 0.2741 - acc: 0.9229 - val_loss: 0.2275 - val_acc: 0.9385
# INFO - test - Completed after 0:00:38
# INFO - test - Running command 'main'
# WARNING - test - No observers have been added to this run
# INFO - test - Started
# /Users/edward.banner/Documents/DSCI6005/instructor/week_5_reinforcement_learning/5_2_pm_nn_training_II/instructor/code/trainers.py:16: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=10, kernel_regularizer=<keras.reg...)`
#   model.add(Dense(units=self.Y[0].shape[0], W_regularizer=l2(self.C['reg'])))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                7850
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________
# Train on 54000 samples, validate on 6000 samples
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO - tensorflow - Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO - tensorflow - Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# Epoch 1/5
# 54000/54000 [==============================] - 5s - loss: 0.4913 - acc: 0.8725 - val_loss: 0.2689 - val_acc: 0.9273
# Epoch 2/5
# 54000/54000 [==============================] - 5s - loss: 0.3137 - acc: 0.9126 - val_loss: 0.2433 - val_acc: 0.9338
# Epoch 3/5
# 54000/54000 [==============================] - 7s - loss: 0.2917 - acc: 0.9186 - val_loss: 0.2366 - val_acc: 0.9342
# Epoch 4/5
# 54000/54000 [==============================] - 5s - loss: 0.2802 - acc: 0.9211 - val_loss: 0.2302 - val_acc: 0.9388
# Epoch 5/5
# 54000/54000 [==============================] - 6s - loss: 0.2733 - acc: 0.9230 - val_loss: 0.2262 - val_acc: 0.9388
# INFO - test - Completed after 0:00:34

# %% [markdown]
# # Multi-Layer Perceptron
#
# - Grid-search over hidden layer size

# %%
from train import ex
import keras.backend as K

for hidden_size in [1, 64, 256]:
    K.clear_session()
    ex.run(config_updates={'trainer': 'MLPTrainer', 'hidden_size': hidden_size})
# Out:
# INFO - test - Running command 'main'
# WARNING - test - No observers have been added to this run
# INFO - test - Started
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 785
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                20
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 805
# Trainable params: 805
# Non-trainable params: 0
# _________________________________________________________________
# Train on 54000 samples, validate on 6000 samples
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO - tensorflow - Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO - tensorflow - Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO - tensorflow - Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO - tensorflow - Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# Epoch 1/5
# 54000/54000 [==============================] - 6s - loss: 2.0310 - acc: 0.2073 - val_loss: 1.9194 - val_acc: 0.2487
# Epoch 2/5
# 54000/54000 [==============================] - 10s - loss: 1.8982 - acc: 0.2694 - val_loss: 1.8486 - val_acc: 0.2875
# Epoch 3/5
# 54000/54000 [==============================] - 7s - loss: 1.8441 - acc: 0.2941 - val_loss: 1.7990 - val_acc: 0.3010
# Epoch 4/5
# 54000/54000 [==============================] - 6s - loss: 1.7967 - acc: 0.3088 - val_loss: 1.7580 - val_acc: 0.3057
# Epoch 5/5
# 54000/54000 [==============================] - 8s - loss: 1.7596 - acc: 0.3044 - val_loss: 1.7260 - val_acc: 0.2977
# INFO - test - Completed after 0:00:43
# INFO - test - Running command 'main'
# WARNING - test - No observers have been added to this run
# INFO - test - Started
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 54000 samples, validate on 6000 samples
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO - tensorflow - Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO - tensorflow - Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO - tensorflow - Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO - tensorflow - Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# Epoch 1/5
# 54000/54000 [==============================] - 11s - loss: 0.3191 - acc: 0.9102 - val_loss: 0.1610 - val_acc: 0.9553
# Epoch 2/5
# 54000/54000 [==============================] - 7s - loss: 0.1560 - acc: 0.9554 - val_loss: 0.1099 - val_acc: 0.9665
# Epoch 3/5
# 54000/54000 [==============================] - 9s - loss: 0.1139 - acc: 0.9664 - val_loss: 0.1054 - val_acc: 0.9688
# Epoch 4/5
# 54000/54000 [==============================] - 7s - loss: 0.0901 - acc: 0.9732 - val_loss: 0.0885 - val_acc: 0.9735
# Epoch 5/5
# 54000/54000 [==============================] - 7s - loss: 0.0736 - acc: 0.9776 - val_loss: 0.0875 - val_acc: 0.9743
# INFO - test - Completed after 0:00:51
# INFO - test - Running command 'main'
# WARNING - test - No observers have been added to this run
# INFO - test - Started
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________
# Train on 54000 samples, validate on 6000 samples
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO - tensorflow - Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO - tensorflow - Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO - tensorflow - Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO - tensorflow - Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# Epoch 1/5
#  - ETA: 7s - loss: 0.3280 - acc: 0.9039
# Epoch 2/5
# 54000/54000 [==============================] - 14s - loss: 0.0979 - acc: 0.9710 - val_loss: 0.0962 - val_acc: 0.9717
# Epoch 3/5
# 54000/54000 [==============================] - 14s - loss: 0.0635 - acc: 0.9800 - val_loss: 0.0742 - val_acc: 0.9773
# Epoch 4/5
#  - ETA: 13s - loss: 0.0440 - acc: 0.9867
# Epoch 5/5
# 54000/54000 [==============================] - 10s - loss: 0.0326 - acc: 0.9901 - val_loss: 0.0732 - val_acc: 0.9807
# INFO - test - Completed after 0:01:21
